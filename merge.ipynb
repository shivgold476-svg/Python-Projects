# %%
import pandas as pd

# %%
name = pd.read_csv("name.csv")
marks = pd.read_csv("marks.csv")

# %%
result = pd.merge(name,marks,on="StudentID")

# %%
print(result)
# Out:
#    StudentID Name  Marks
# 0          1    A     80
# 1          2    B     90
# 2          3    C     82
# 3          4    D     75
